# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %config InlineBackend.figure_format='retina'
import seaborn as sns

# %%
raw_data = pd.read_json('food_enforcement_US_bacteria.json', orient='records')

# %%
print(raw_data.shape)
print(raw_data.head(10).product_description)
# Out:
# (6104, 26)
# 0    Native Catch Salmon Bacon, Traditional flavor....
# 1    Delish Fruit Burst 10 oz.(283 g)  Enjoy by: 8/...
# 2    Garden Pure Holiday Fruit Bowl 4 lbs (1.81kg) ...
# 3    Fresh Fruit Product is labeled in part:  "***F...
# 4    Ready PacÂ¿ Gourmet Fruit Bowl, 64oz , UPC 777...
# 5    River Ranch brand Diced Grn Cabbage w/Color, 4...
# 6    Sweet and Sour Stir Fry packaged under the fol...
# 7    Onion Slab Cut.  Products are labeled in part:...
# 8    MIX w/yellow onions used as an ingredient.  Pr...
# 9    Fresh n Easy brand Shred Grn Cabbage w/Color, ...
# Name: product_description, dtype: object

# %% [markdown]
# ### Features with all words

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# vectorizer = CountVectorizer()

from sklearn.feature_extraction.text import HashingVectorizer
vectorizer = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)

corpus = raw_data['product_description']
X = vectorizer.fit_transform(corpus)
X.shape

# %% [markdown]
# ### Final feature set

# %%
from sklearn.feature_extraction.text import HashingVectorizer
vectorizer = HashingVectorizer(n_features=2 ** 17, alternate_sign=False)

corpus = []
raw_data['product_description'] = raw_data['product_description'].str.replace('[^\w\s]','')

# import nltk
# nltk.download('stopwords')

common=['oz','lb','lbs','product','packaged','code','brand','upc','packed','sold','distributed','net','wt','g','inc','item','labeled','label','ca','llc','date','bag','bags','weight','case','container','plastic','per','size','individually','containers','kg','film']
s=set(stopwords.words('english')+common)

for i in range(0,len(raw_data['product_description'])):
    txt=raw_data.product_description[i].lower()
    str_list = txt.split()

    stri = ' '.join(set(str_list) - s)
    corpus += [stri]
    
# print(corpus)
X = vectorizer.fit_transform(corpus)
X.shape
# Out:
# (6104, 131072)

# %% [markdown]
# ### Elbow plot

# %%
from sklearn.cluster import KMeans
kmeans_kwargs = {
    "init": "random",
    "n_init": 15,
    "max_iter": 300,
    "random_state": 22,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 50):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# %%
 plt.style.use("fivethirtyeight")
 plt.plot(range(1, 50), sse)
 plt.xticks(range(1, 50))
 plt.xlabel("Number of Clusters")
 plt.ylabel("SSE")
 plt.show()

# %% [markdown]
# ### Silhouette

# %%
range_n_clusters = [15]

# %%
# modified from: http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import random

for n_clusters in range_n_clusters:
    # Create a subplot
    fig, (ax1) = plt.subplots(1, 1)
    fig.set_size_inches(9, 17)

    # The silhouette coefficient can range from -1, 1 but in this example all lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate them clearly.
#     ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
    ax1.set_ylim([0, 6000 + (n_clusters + 1) * 10])
    
    kmeans_kwargs = {
        "n_init": 20,
        "max_iter": 1000,
        "random_state": 54,
    }

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, **kmeans_kwargs)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        # select a random color for this cluster
        r = lambda: random.randint(0,255)
        color = '#%02X%02X%02X' % (r(),r(),r())
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
#         ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

    plt.show()
# Out:
# For n_clusters = 15 The average silhouette_score is : 0.05250992765271053

# %% [markdown]
# ### fit Kmeans

# %%
#fit Kmeans with k clusters
from sklearn.cluster import KMeans

kmeans_kwargs = {
        "n_init": 20,
        "max_iter": 1000,
        "random_state": 54,
    }

km = KMeans(n_clusters=15, **kmeans_kwargs)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=15, n_init=20, n_jobs=None, precompute_distances='auto',
#     random_state=54, tol=0.0001, verbose=0)

# %% [markdown]
# ### labels are named with integers and stored in the `labels_` attribute

# %%
km.labels_
# Out:
# array([0, 0, 3, ..., 0, 0, 0])

# %%
def countX(lst, x): 
    count = 0
    for ele in lst: 
        if (ele == x): 
            count = count + 1
    return count 

for i in range(0,15):
    # Driver Code 
    lst = km.labels_ 
    x = i
    print('{} has occurred {} times'.format(x, countX(lst, x)))
# Out:
# 0 has occurred 2532 times
# 1 has occurred 157 times
# 2 has occurred 158 times
# 3 has occurred 251 times
# 4 has occurred 243 times
# 5 has occurred 392 times
# 6 has occurred 165 times
# 7 has occurred 431 times
# 8 has occurred 468 times
# 9 has occurred 329 times
# 10 has occurred 229 times
# 11 has occurred 107 times
# 12 has occurred 87 times
# 13 has occurred 345 times
# 14 has occurred 210 times

# %% [markdown]
# ### take a look at one of the cluster results

# %%
# You should look at all the clusters, but let's look at cluster "15" (I chose this arbitrarily; you should look at all of them)
# print(len(km.labels_))
for i in range(0,len(km.labels_)):
    if km.labels_[i] == 6:
        print(raw_data['product_description'][i])
#         print(corpus[i])
        print('**********')
# Out:
# Prime Time brand Buckeye Bites Ice Cream in a paper carton    oz containers and  gallon tubs
# **********
# Black Current Italian Ice  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Chip Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Ginger Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Truffle Mint Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Mango Italian Ice Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Cinnamon Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Sweet Cream Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Restaurant SO Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Rocky Road Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Lavender Peppermint Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Vanilla Bean Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Lemon Custard Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Eggnog Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Marionberry Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
#  Special Order Other Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Butter Brickle Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Blind Love Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Marionberry Sherbet  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Strawberry Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Oreo Cookie Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Macaroon Bisque    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Dutch Malt Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Toasted Coconut Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Black Forest Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Coffee Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Green Tea Ice Cream     Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Coffee Oreo Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# SWORCH Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Strawberry Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Pumpkin Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Oreo Mint Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Lavender White Chocolate Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Root Beer Float Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# White Chocolate Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Gooseberry Italian Ice Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Banana Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Amaretto Hazelnut Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Brandied Apricot Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Almond Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Date Nut Victoria Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Local Raspberry Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Spumoni Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Raspberry Italian Ice  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Licorice Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Mexican Chocolate Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Lavender Lemon Custard Ice Cream   Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Coconut Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Vanilla Mint Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Pineapple Raspberry Italian Ice  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Espresso Chip Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Root Beer Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Cranberry Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Tiramisu Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Pina Colada Italian Ice  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Mint Chip Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Cardamom Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Peppermint Candy Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Triple Citrus Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Chip Swirl Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Apple Cider Italian Ice  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Maple Walnut Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Raspberry Sherbet    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Ginger Snap Ice Cream  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Special Order OtherSherbet  Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Blueberry Italian Ice    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Chocolate Almond Swirl Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Vanilla Ice Cream    Product can be packaged in  gallon or  gallon plastic tubs or cardboard quart container  Firm is unable to determine how batches were packaged
# **********
# Lemon Perfection Custard sold under Snoqualmie brand  Product is sold in  oz pint paper cartons and  gallon plastic tubs  No UPC
# **********
# Lemon Custard sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Double Chocolate Custard sold under Snoqualmie brand Product is sold in  gallon plastic tubs  No UPC
# **********
# Lime Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Gelato Mix sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic bags No UPC
# **********
# Lemon Lime Sorbet sold under Snoqualmie brand  Product is sold in  oz pint paper cartons and  and  gallon plastic tubs No UPC
# **********
# Strawberry Cosmo Lemon Twist Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Grapefruit Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Pear Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# LemoncelloMint Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Apricot Mango Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Chocolate Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Peach Champagne Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs in addition to a number of unknown sizes No UPC
# **********
# Guava Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Coconut Rum Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Coconut Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Passion Fruit Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Cranberry Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Honey Cinnamon Custard with soy lecithin sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Rosewater Pistachio Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Cranberry Orange Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Pistachio Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic trays  and  gallon plastic tubs and other unknown container typesizes  No UPC
# **********
# MandarineTangerine Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Raspberry Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Chocolate Chip Cookie Dough Custard sold under Snoqualmie brand Product is sold in  gallon plastic trays and  gallon plastic tubs  No UPC
# **********
# Honey Raspberry Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Pear Ginger Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# English Toffee Custard sold under Snoqualmie brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Blueberry Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Champagne Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Pumpkin Custard with soy lecithin sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Checkered Chocolate Custard sold under Snoqualmie brand Product is sold in  gallon plastic tub and  oz pint paper cartons  No UPC
# **********
# Cherry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Pear Bartlett Pear Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Four SorbetsDifferent ones sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Strawberry Basil Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Sorbet Cosmo Lemon Twist sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Sorbet Base sold under Snoqualmie brand  Product is sold in  gallon plastic bags No UPC
# **********
# Turkish Coast Coffee Custard sold under Snoqualmie brand  Product is sold in  gallon plastic trays No UPC
# **********
# Mango Passion Fruit Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs in addition to a quantity of unknown sizes No UPC
# **********
# Berry Ripple Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Lemon Thyme Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Pomegranate Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Creme Fraiche with soy lecithin Gelato sold under Snoqualmie Ice  Cream brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Blackberry Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Cookie Dough Custard sold under Snoqualmie brand Product is sold in  gallon plastic tubs  No UPC
# **********
# Chocolate Brilliance Gelato sold under Snoqualmie brand  Product is sold in  oz pint paper cartons  and  gallon plastic tubs No UPC
# **********
# Berry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic trays No UPC
# **********
# Watermelon Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Lemon Basil Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Lavender Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Lemon Sorbet with Lemon Swirl sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Double Chocolate Custard with Peanuts sold under Snoqualmie brand Product is sold in  gallon plastic tubs  No UPC
# **********
# Double Chocolate Custard with Espresso sold under Snoqualmie brand Product is sold in  gallon plastic tubs  No UPC
# **********
# Pear Champagne Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Pomegranate Cranberry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Strawberry Rhubarb Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Blood Orange Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Coconut Pineapple Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Orange Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Pineapple Coconut Rum Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Lemon Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic trays and  and  gallon plastic tubs No UPC
# **********
# Blueberry Ginger Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Peach Sorbet sold under Snoqualmie brand  Product is sold in  gallon trays  and  gallon plastic tubs and a number of unknown sizes No UPC
# **********
# Lemon Meyer Sorbet Meyer Lemon sold under Snoqualmie brand  Product is sold in  gallon or  gallon plastic tubs No UPC and no labels provided
# **********
# Apricot Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Apple Cider Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Cranberry Raspberry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic trays  and  gallon plastic tubs No UPC
# **********
# Key Lime Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Orange Pomegranate Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Peppermint Stick with lecithin Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic trays  and  gallon plastic tubs  No UPC
# **********
# French Vanilla Custard with soy lecithin sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Blackberry Cabernet Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Strawberry Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Pink Champagne Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Raspberry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic trays  and  gallon plastic tubs No UPC
# **********
# Pumpkin Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Bold Espresso Custard sold under Snoqualmie brand Product is sold in  gallon plastic tubs and  oz pint paper cartons  No UPC
# **********
# Egg Nog sold under Snoqualmie brand Product is sold in  gallon plastic trays and  gallon plastic tubs  No UPC
# **********
# Chocolate Custard with Espresso Chips sold under Snoqualmie brand Product is sold in  gallon plastic tubs  No UPC
# **********
# Reisling Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Pineapple Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Mojito Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Cherry Vanilla  Custard without egg sold under Snoqualmie brand Product is sold in  and  gallon plastic tubs  No UPC
# **********
# Hazelnut Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs in addition to other unknown sizecontainers No UPC
# **********
# Almond Buttercrunch Toffee Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic trays No UPC
# **********
# Pomegranate Raspberry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Mango Pistachio Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic tubs  No UPC
# **********
# Pineapple Basil Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Mango Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Raspberry Pomegranate Sorbet sold under Snoqualmie brand  Product is sold in  oz pint paper cartons  gallon plastic trays  and  gallon plastic tubs No UPC
# **********
# Cucumber Lime Sorbet sold under Snoqualmie brand  Product is sold in  and  gallon plastic tubs No UPC
# **********
# Apple Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic tubs No UPC
# **********
# Mixed Berry Sorbet sold under Snoqualmie brand  Product is sold in  gallon plastic trays  and  gallon plastic tubs No UPC
# **********
# Gianduja Gelato sold under Snoqualmie Ice Cream brand  Product is sold in  gallon plastic trays No UPC
# **********

# %% [markdown]
# ### Check cluster word counts

# %%
# You should look at all the clusters, but let's look at cluster "15" (I chose this arbitrarily; you should look at all of them)
# print(len(km.labels_))
text = []
for i in range(0,len(km.labels_)):
    if km.labels_[i] == 11:
        txt = corpus[i]
        str_list = txt.split()

        stri = ' '.join(set(str_list))
        text += [stri]
print(Counter(" ".join(text).split()).most_common(10))
# Out:
# [('whole', 106), ('foods', 106), ('market', 106), ('upcplu', 75), ('peach', 37), ('bar', 18), ('prepared', 17), ('listed', 17), ('selfservice', 17), ('chefs', 17)]

# %% [markdown]
# ### Pull common words from all items

# %%
from collections import Counter

print(Counter(" ".join(corpus).split()).most_common(300))
# print(corpus)
# Out:
# [('plastic', 1167), ('salad', 784), ('foods', 714), ('cream', 641), ('ice', 641), ('gallon', 482), ('fresh', 470), ('case', 467), ('container', 459), ('cheese', 438), ('butter', 394), ('frozen', 386), ('chocolate', 377), ('per', 360), ('bag', 345), ('bags', 340), ('clear', 340), ('organic', 340), ('blue', 336), ('peanut', 323), ('size', 312), ('gardenfresh', 309), ('ingredients', 305), ('milk', 303), ('bulk', 299), ('mix', 293), ('whole', 292), ('part', 276), ('bell', 274), ('market', 264), ('carton', 261), ('best', 259), ('retail', 256), ('refrigerated', 255), ('cases', 251), ('potato', 245), ('box', 243), ('salt', 242), ('number', 238), ('tubs', 237), ('red', 236), ('white', 236), ('name', 233), ('natural', 232), ('flavor', 222), ('formula', 222), ('co', 214), ('weight', 214), ('package', 211), ('sugar', 207), ('pint', 207), ('smoked', 206), ('keep', 202), ('raw', 196), ('bar', 194), ('containers', 187), ('green', 184), ('fruit', 183), ('manufactured', 183), ('farms', 180), ('cardboard', 179), ('individually', 178), ('salmon', 172), ('fine', 172), ('black', 166), ('following', 165), ('bean', 165), ('soy', 165), ('yellow', 163), ('pack', 162), ('roasted', 160), ('resers', 160), ('creamy', 159), ('kg', 155), ('paper', 154), ('beaverton', 152), ('powder', 150), ('food', 150), ('river', 145), ('traditions', 139), ('tub', 139), ('products', 137), ('finest', 137), ('ranch', 136), ('vanilla', 134), ('creams', 134), ('jenis', 134), ('splendid', 134), ('pasta', 133), ('mfg', 132), ('sizes', 130), ('film', 129), ('bucket', 129), ('vacuum', 128), ('kit', 128), ('x', 127), ('almond', 127), ('corn', 125), ('onions', 123), ('firm', 122), ('dip', 121), ('processed', 119), ('broccoli', 119), ('blend', 117), ('ready', 116), ('vegetable', 116), ('snoqualmie', 115), ('gallons', 114), ('onion', 112), ('style', 112), ('wa', 112), ('pepper', 111), ('packages', 110), ('foodservice', 108), ('po', 107), ('tray', 106), ('cup', 106), ('contains', 106), ('farm', 105), ('ny', 105), ('california', 103), ('gum', 103), ('sunland', 103), ('road', 102), ('bars', 102), ('usa', 101), ('affixed', 101), ('garden', 100), ('trays', 99), ('free', 99), ('sunflower', 99), ('half', 99), ('protein', 98), ('pints', 98), ('lecithin', 97), ('slaw', 95), ('spread', 95), ('cheddar', 95), ('carob', 95), ('refrigerate', 94), ('cut', 94), ('labels', 94), ('bagged', 93), ('sandwich', 93), ('polyethylene', 92), ('eat', 92), ('used', 92), ('sliced', 92), ('hot', 92), ('fl', 91), ('within', 91), ('egg', 90), ('peanuts', 89), ('crunchy', 89), ('consume', 88), ('pounds', 88), ('sorbet', 88), ('polypropylenepolyethylene', 87), ('chicken', 87), ('garlic', 87), ('qts', 87), ('snack', 86), ('nuts', 86), ('syrup', 86), ('cake', 86), ('apple', 85), ('beans', 85), ('seafood', 85), ('unit', 84), ('nut', 84), ('ashers', 84), ('brands', 83), ('pa', 83), ('gal', 83), ('still', 83), ('mango', 82), ('valley', 82), ('oil', 82), ('deli', 82), ('scale', 82), ('carrots', 82), ('company', 81), ('salted', 81), ('sweet', 80), ('labeling', 80), ('wheat', 80), ('dark', 80), ('fish', 79), ('salsa', 78), ('cole', 78), ('classic', 78), ('dist', 78), ('dairy', 78), ('italian', 77), ('cups', 77), ('skim', 77), ('water', 76), ('quart', 76), ('boxes', 75), ('park', 75), ('c', 75), ('guar', 75), ('coconut', 75), ('one', 75), ('upcplu', 75), ('sysco', 74), ('stores', 73), ('mixed', 73), ('nj', 72), ('harvest', 72), ('ave', 72), ('grade', 72), ('diced', 71), ('us', 71), ('ml', 71), ('safeway', 70), ('also', 69), ('tuna', 69), ('cold', 69), ('brown', 69), ('determine', 69), ('unable', 69), ('batches', 69), ('poly', 68), ('count', 68), ('la', 68), ('sprouts', 67), ('seattle', 67), ('produced', 67), ('ga', 67), ('sea', 67), ('solids', 67), ('gluten', 67), ('lid', 66), ('peas', 66), ('caramel', 66), ('wild', 66), ('trail', 65), ('yogurt', 65), ('cookie', 64), ('il', 63), ('gourmet', 63), ('sealed', 63), ('units', 62), ('herring', 62), ('grandpas', 62), ('single', 62), ('chip', 62), ('cashew', 61), ('strawberry', 60),  ...
